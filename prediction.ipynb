# %%
from ultralytics import YOLO

model = YOLO('F:\Projects\Fetal abnormality object detection.v1i.yolov8\yolov8n.pt') 
model.train(data="F:\Projects\Fetal abnormality object detection.v1i.yolov8\data.yaml", epochs=5,batch=4)  # train the model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 5.02MB/s]
# New https://pypi.org/project/ultralytics/8.1.16 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.14 🚀 Python-3.9.0 torch-2.0.0+cpu CPU (Intel Core(TM) i5-10500H 2.50GHz)
# ...

# %%
import cv2
from ultralytics import YOLO
model=YOLO("runs/detect/train/weights/best.pt")

# %%
def predict(chosen_model, img, classes=[], conf=0.5):
    if classes:
        results = chosen_model.predict(img, classes=classes, conf=conf)
    else:
        results = chosen_model.predict(img, conf=conf)

    return results


def predict_and_detect(chosen_model, img, classes=[], conf=0.5):
    results = predict(chosen_model, img, classes, conf=conf)

    for result in results:
        for box in result.boxes:
            cv2.rectangle(img, (int(box.xyxy[0][0]), int(box.xyxy[0][1])),
                          (int(box.xyxy[0][2]), int(box.xyxy[0][3])), (255, 0, 0), 2)
            cv2.putText(img, f"{result.names[int(box.cls[0])]}",
                        (int(box.xyxy[0][0]), int(box.xyxy[0][1]) - 10),
                        cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 1)
    return img, results

# %%
image = cv2.imread("valid\images\encephalocele-3-23b_png.rf.27556f9c8a16ad0227b39796accfd46b.jpg")
result_img,_ = predict_and_detect(model, image, classes=[0, 1], conf=0.5)
# Out:
# 0: 640x640 1 abnormal, 301.2ms
# Speed: 4.3ms preprocess, 301.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
_
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abnormal', 1: 'normal'}
#  obb: None
#  orig_img: array([[[52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52],
#          ...,
#          [52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52]],
#
#         [[52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52],
#          ...,
#          [52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52]],
#
#         [[52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52],
#          ...,
#          [52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52]],
#
#         ...,
#
#         [[52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52],
#          ...,
#          [52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52]],
#
#         [[52, 52, 52],
#          [52, 52, 52],
#          [52, 52, 52],
#          ...,
# ...

# %%
import numpy as np

def nms(predictions, threshold):
    """
    Performs non-maximum suppression on the input predictions.

    Args:
        predictions: A list of detections, where each detection is a tuple of (score, x1, y1, x2, y2).
        threshold: The threshold for suppressing detections.

    Returns:
        A list of detections after non-maximum suppression.
    """
    detections = sorted(predictions, key=lambda x: x[0], reverse=True)
    suppressed_detections = []
    while detections:
        detection = detections.pop(0)
        suppressed_detections.append(detection)
        for detection2 in detections:
            if IOU(detection, detection2) > threshold:
                detections.remove(detection2)
    return suppressed_detections

def IOU(detection1, detection2):
    """
    Calculates the Intersection over Union (IoU) between two detections.

    Args:
        detection1: A detection, where the detection is a tuple of (score, x1, y1, x2, y2).
        detection2: A detection, where the detection is a tuple of (score, x1, y1, x2, y2).

    Returns:
        The IoU between the two detections.
    """
    x1 = max(detection1[1], detection2[1])
    y1 = max(detection1[2], detection2[2])
    x2 = min(detection1[3], detection2[3])
    y2 = min(detection1[4], detection2[4])
    intersection = max(0, x2 - x1 + 1) * max(0, y2 - y1 + 1)
    union = (detection1[3] - detection1[1] + 1) * (detection1[4])

# %%
import matplotlib.pyplot as plt

plt.imshow(cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB))
plt.show()
